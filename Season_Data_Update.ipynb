# %%
import pandas as pd

# %%
df = pd.read_csv('data/2014.csv')
df
# Out:
#                                 Team  Gms  Tot Pts  Pts/G  RushYds  RYds/G  \
# 0            Seattle SeahawksSeattle   16      254   15.9     1304    81.5
# 1               Detroit LionsDetroit   16      282   17.6     1109    69.3
# 2               Denver BroncosDenver   16      354   22.1     1276    79.8
# 3               Buffalo BillsBuffalo   16      289   18.1     1703   106.4
# 4   San Francisco 49ersSan Francisco   16      340   21.2     1612   100.8
# 5               New York JetsNY Jets   16      401   25.1     1489    93.1
# 6      Kansas City ChiefsKansas City   16      281   17.6     2036   127.2
# 7          Baltimore RavensBaltimore   16      302   18.9     1412    88.2
# 8        San Diego ChargersSan Diego   16      348   21.8     1986   124.1
# 9          Carolina PanthersCarolina   16      374   23.4     1792   112.0
# 10    Indianapolis ColtsIndianapolis   16      369   23.1     1814   113.4
# ...

# %%
playoff = ['True', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False']

# %%
df['Playoff'] = playoff
df
# len(playoff), playoff.count('True'), playoff.count('False')
# Out:
#                                 Team  Gms  Tot Pts  Pts/G  RushYds  RYds/G  \
# 0            Seattle SeahawksSeattle   16      254   15.9     1304    81.5
# 1               Detroit LionsDetroit   16      282   17.6     1109    69.3
# 2               Denver BroncosDenver   16      354   22.1     1276    79.8
# 3               Buffalo BillsBuffalo   16      289   18.1     1703   106.4
# 4   San Francisco 49ersSan Francisco   16      340   21.2     1612   100.8
# 5               New York JetsNY Jets   16      401   25.1     1489    93.1
# 6      Kansas City ChiefsKansas City   16      281   17.6     2036   127.2
# 7          Baltimore RavensBaltimore   16      302   18.9     1412    88.2
# 8        San Diego ChargersSan Diego   16      348   21.8     1986   124.1
# 9          Carolina PanthersCarolina   16      374   23.4     1792   112.0
# 10    Indianapolis ColtsIndianapolis   16      369   23.1     1814   113.4
# ...

# %%
df.to_csv('data/2014_Update.csv', index=False)
