# %%
import pandas as pd

# %%
df = pd.read_csv('data/2019.csv')
df
# Out:
#                                 Team  Gms  Tot Pts  Pts/G  RushYds  RYds/G  \
# 0    New England PatriotsNew England   16      225   14.1     1528    95.5
# 1   San Francisco 49ersSan Francisco   16      310   19.4     1802   112.6
# 2               Buffalo BillsBuffalo   16      259   16.2     1649   103.1
# 3          Baltimore RavensBaltimore   16      282   17.6     1494    93.4
# 4      Pittsburgh SteelersPittsburgh   16      303   18.9     1753   109.6
# 5    Los Angeles ChargersLA Chargers   16      345   21.6     1805   112.8
# 6               New York JetsNY Jets   16      359   22.4     1391    86.9
# 7               Chicago BearsChicago   16      298   18.6     1632   102.0
# 8               Dallas CowboysDallas   16      321   20.1     1656   103.5
# 9    Philadelphia EaglesPhiladelphia   16      354   22.1     1442    90.1
# 10     New Orleans SaintsNew Orleans   16      341   21.3     1461    91.3
# ...

# %%
playoff = ['True', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False']

# %%
df['Playoff'] = playoff
df
# len(playoff), playoff.count('True'), playoff.count('False')
# Out:
#                                 Team  Gms  Tot Pts  Pts/G  RushYds  RYds/G  \
# 0    New England PatriotsNew England   16      225   14.1     1528    95.5
# 1   San Francisco 49ersSan Francisco   16      310   19.4     1802   112.6
# 2               Buffalo BillsBuffalo   16      259   16.2     1649   103.1
# 3          Baltimore RavensBaltimore   16      282   17.6     1494    93.4
# 4      Pittsburgh SteelersPittsburgh   16      303   18.9     1753   109.6
# 5    Los Angeles ChargersLA Chargers   16      345   21.6     1805   112.8
# 6               New York JetsNY Jets   16      359   22.4     1391    86.9
# 7               Chicago BearsChicago   16      298   18.6     1632   102.0
# 8               Dallas CowboysDallas   16      321   20.1     1656   103.5
# 9    Philadelphia EaglesPhiladelphia   16      354   22.1     1442    90.1
# 10     New Orleans SaintsNew Orleans   16      341   21.3     1461    91.3
# ...

# %%
# df.to_csv('data/2019_Update.csv', index=False)
